# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./ufc-fighters-statistics.csv')
data
# Out:
#                    name    nickname  wins  losses  draws  height_cm  \
# 0       Robert Drysdale         NaN     7       0      0     190.50
# 1     Daniel McWilliams  The Animal    15      37      0     185.42
# 2            Dan Molina         NaN    13       9      0     177.80
# 3             Paul Ruiz         NaN     7       4      0     167.64
# 4       Collin Huckbody      All In     8       2      0     190.50
# ...                 ...         ...   ...     ...    ...        ...
# 4106    John Campetella         NaN     0       1      0     175.26
# 4107  Andre Pederneiras         NaN     1       1      2     172.72
# 4108      Bryson Kamaka         NaN    12      20      1     180.34
# 4109        Matej Penaz       Money     6       1      0     190.50
# 4110     Pauline Macias        PITA     4       1      0     162.56
#
#       weight_in_kg  reach_in_cm    stance date_of_birth  \
# 0            92.99          NaN  Orthodox    1981-10-05
# ...

# %%
# Exercise 1: Basic Filtering
"""
1. Filter fighters who have more than 20 wins
2. Sort these fighters by wins in descending order
3. Select only the name, nickname, and wins columns
Your code here:
"""
# Out:
# '\n1. Filter fighters who have more than 20 wins\n2. Sort these fighters by wins in descending order\n3. Select only the name, nickname, and wins columns\nYour code here:\n'

# %%
# Exercise 2: Missing Data Analysis
"""
1. Count total number of fighters
2. Count fighters with missing stance information
3. Calculate percentage of fighters with missing stance
(missing_stance / len(data)) * 100
Your code here:
"""
# Out:
# '\n1. Count total number of fighters\n2. Count fighters with missing stance information\n3. Calculate percentage of fighters with missing stance\n(missing_stance / len(data)) * 100\nYour code here:\n'

# %%
# Exercise 3: Weight Class Distribution
"""
1. Create a new column 'weight_class' based on weight_in_kg:
   - Under 65.8 kg: 'Featherweight'
   - 65.8-70.3 kg: 'Lightweight'
   - 70.3-77.1 kg: 'Welterweight'
   - 77.1-83.9 kg: 'Middleweight'
   - Above 83.9 kg: 'Heavyweight'
2. Count number of fighters in each weight class
Your code here:
"""
# Out:
# "\n1. Create a new column 'weight_class' based on weight_in_kg:\n   - Under 65.8 kg: 'Featherweight'\n   - 65.8-70.3 kg: 'Lightweight'\n   - 70.3-77.1 kg: 'Welterweight'\n   - 77.1-83.9 kg: 'Middleweight'\n   - Above 83.9 kg: 'Heavyweight'\n2. Count number of fighters in each weight class\nYour code here:\n"

# %%
# Exercise 4: Win-Loss Ratio
"""
1. Create a 'win_loss_ratio' column (wins / losses)
2. Filter out fighters with 0 losses
3. Group by stance and calculate average win_loss_ratio
4. Sort stances by average win_loss_ratio
Your code here:
"""
# Out:
# "\n1. Create a 'win_loss_ratio' column (wins / losses)\n2. Filter out fighters with 0 losses\n3. Group by stance and calculate average win_loss_ratio\n4. Sort stances by average win_loss_ratio\nYour code here:\n"

# %%
# Exercise 5: Takedown Analysis
"""
1. Create a new column 'takedown_accuracy_decimal' =  takedown_accuracy / 100
2. Create a new column 'takedown_effectiveness' = average_takedowns_landed_per_15_minutes *
takedown_accuracy_decimal.round(2)
3. Filter takedown_effectiveness > 0 and display [nickname, takedown_effectiveness'] 
Fill empty nickname with 'Unknown'
Your code here:
"""
# Out:
# "\n1. Create a new column 'takedown_accuracy_decimal' =  takedown_accuracy / 100\n2. Create a new column 'takedown_effectiveness' = average_takedowns_landed_per_15_minutes *\ntakedown_accuracy_decimal.round(2)\n3. Filter takedown_effectiveness > 0 and display [nickname, takedown_effectiveness'] \nFill empty nickname with 'Unknown'\nYour code here:\n"

# %%
# Exercise 6: Fighter Experience
"""
1. Create total_fights column (wins + losses + draws)
2. Group fighters into experience levels (rookie: <5, experienced: 5-15, veteran: >15)
Using apply and mapping function
3. Calculate average significant_striking_accuracy per experience level group
Your code here:
"""
# Out:
# '\n1. Create total_fights column (wins + losses + draws)\n2. Group fighters into experience levels (rookie: <5, experienced: 5-15, veteran: >15)\nUsing apply and mapping function\n3. Calculate average significant_striking_accuracy per experience level group\nYour code here:\n'
